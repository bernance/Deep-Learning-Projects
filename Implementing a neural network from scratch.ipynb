# %%
import numpy as np

# %%
import math

# %%
# defining sigmoid function
def sigmoid(z):
    return(1/(1+np.exp(-z)))

# %%
#defining log loss function
def log_loss(y_true, y_pred):
    epsilon = 1e-15
    y_pred_new = [max(i, epsilon) for i in y_pred]
    y_pred_new = [min(i, 1-epsilon) for i in y_pred_new]
    y_pred_new = np.array(y_pred_new)
    return -np.mean(y_true * np.log(y_pred_new) + (1-y_true) * np.log(1-y_pred_new))

# %%
class MyNn():
    def __init__(self):
        self.w1 = 1
        self.w2 = 1
        self.bias = 0

    def fit(self, x, y, epochs, max_loss):
        self.w1, self.w2, self.bias = self.gradient_descent(a, b, y_true, epochs, max_loss)
        
    def predict(self, x):
        weighted_sum = w1*a + w2*b + bias
        return sigmoid(weighted_sum)

        
    def gradient_descent(self, a, b, y_true, epochs, max_loss):
        rate = 0.1
        n = len(a)

        for i in range(epochs):
            weighted_sum = w1*a + w2*b + bias
            y_pred = sigmoid(weighted_sum)

            loss = log_loss(y_true, y_pred)

            w1d = (1/n)* np.dot(np.transpose(a), (y_pred - y_true))
            w2d = (1/n)* np.dot(np.transpose(b), (y_pred - y_true))

            bias_d = np.mean(y_pred-y_true)

            w1 = w1 - rate * w1d
            w2 = w2- rate * w2d

            bias = bias - rate * bias_d

            if epoch % 50 == 0:
                print(f"Epoch: {i}, w1: {w1}, w2: {w2}, bias: {bias}, loss: {loss}")

            if loss <= max_loss:
                print(f"Epoch: {i}, w1: {w1}, w2: {w2}, bias: {bias}, loss: {loss}")
                break
        

        return w1, w2, bias

# %%
# def gradient_descent(a,b, y_true, epochs):
#     w1 = w2 = 1
#     bias = 0
#     rate = 0.1
#     n = len(a)

#     for i in range(epochs):
#         weighted_sum = w1*a + w2*b + bias
#         y_pred = sigmoid(weighted_sum)

#         loss = log_loss(y_true, y_pred)

#         w1d = (1/n)* np.dot(np.transpose(a), (y_pred - y_true))
#         w2d = (1/n)* np.dot(np.transpose(b), (y_pred - y_true))

#         bias_d = np.mean(y_pred-y_true)

#         w1 = w1 - rate * w1d
#         w2 = w2- rate * w2d

#         bias = bias - rate * bias_d

#         print(f"Epoch: {i}, w1: {w1}, w2: {w2}, bias: {bias}, loss: {loss}")

#     return w1, w2, bias

# %%
import pandas as pd

# %%
df = pd.read_csv("insurance_data.csv")

# %%
from sklearn.model_selection import train_test_split

# %%
df.head()
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age', 'affordibility']], df.bought_insurance, test_size=0.2, random_state=20 )

# %%
X_test_scaled = X_test.copy()
X_test_scaled['age'] = X_test_scaled['age']/100

# %%
X_train_scaled = X_train.copy()
X_train_scaled['age'] = X_train_scaled['age']/100

# %%
import tensorflow
from tensorflow import keras
# Out:
# 2026-06-14 12:41:27.483580: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = keras.Sequential([
    keras.layers.Dense(1,input_shape=(2,),activation='sigmoid', kernel_initializer='ones', bias_initializer='zeros')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.fit(X_train_scaled, y_train, epochs=500)
# Out:
# /Users/mac/tensorflow_env/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 750ms/step - accuracy: 0.5909 - loss: 0.6459
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5909 - loss: 0.6456
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5909 - loss: 0.6454
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5909 - loss: 0.6451
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5909 - loss: 0.6448
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5909 - loss: 0.6446
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5909 - loss: 0.6443
# Epoch 8/500
# ...
